# %%
import pandas as pd 
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
Drop any four rows from the data set.
Return 3 rows from the bottom.
Return 6 rows from the head.
Return any 15 rows from the mid 
find the mean,count,min,max from this dataset.

count the values of any two columns.
Take some data as you want and make a bar graph on this data.
Find the mean any specific column.

Drop any two colmns.
find two columns and six rows from the mid.

Show the number of rows and columns in the data set

Getting the frequency of most of the match awards

Getting the top 10 players with the most man of the match awards.
 
Finding out the number of toss wins w.r.t each team

Extracting the records where a team won batting first.

Make a bar plot for the top 5 players with most man of the match awards.

Making a pie chart or bar graph for distribution of most wins after batting second.

Looking at the number of matches played each season.''

# %%
df=pd.read_csv("C:/Users/hp/OneDrive/Documents/matches.csv.xls")
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# Check the how much row and columns are in the data set
df.shape
# Out:
# (756, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
# returning 3 row from last 
df.tail(3)
# Out:
#         id    Season           city        date                team1  \
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019  Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019       Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 753           0       Delhi Capitals            0               2
# 754           0  Chennai Super Kings            0               6
# 755           0       Mumbai Indians            1               0
#
#     player_of_match                               venue        umpire1  \
# 753         RR Pant                    ACA-VDCA Stadium            NaN
# ...

# %%
# returning 6 row from above
df.head(6)
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6  IPL-2017  Hyderabad  09-04-2017                Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# ...

# %%
# retuning from middle 
df.iloc[5:20,:]
# Out:
#     id    Season       city        date                        team1  \
# 5    6  IPL-2017  Hyderabad  09-04-2017                Gujarat Lions
# 6    7  IPL-2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7    8  IPL-2017     Indore  10-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 9   10  IPL-2017     Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  11  IPL-2017    Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017  Bangalore  14-04-2017  Royal Challengers Bangalore
# 12  13  IPL-2017     Rajkot  14-04-2017       Rising Pune Supergiant
# 13  14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14  15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
# 15  16  IPL-2017     Mumbai  16-04-2017                Gujarat Lions
# 16  17  IPL-2017  Bangalore  16-04-2017       Rising Pune Supergiant
# 17  18  IPL-2017      Delhi  17-04-2017             Delhi Daredevils
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df.fillna(00,inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %%
# count the values of any two columns.
df.sum()
# Out:
# id                                                          1354887
# Season            IPL-2017IPL-2017IPL-2017IPL-2017IPL-2017IPL-20...
# date              05-04-201706-04-201707-04-201708-04-201708-04-...
# team1             Sunrisers HyderabadMumbai IndiansGujarat Lions...
# team2             Royal Challengers BangaloreRising Pune Supergi...
# toss_winner       Royal Challengers BangaloreRising Pune Supergi...
# toss_decision     fieldfieldfieldfieldbatfieldfieldbatfieldfield...
# result            normalnormalnormalnormalnormalnormalnormalnorm...
# dl_applied                                                       19
# win_by_runs                                                   10042
# win_by_wickets                                                 2533
# venue             Rajiv Gandhi International Stadium, UppalMahar...
# dtype: object

# %%
a=df.loc[:,'player_of_match']
print(a)
# a.sum()
# Out:
# 0      Yuvraj Singh
# 1         SPD Smith
# 2           CA Lynn
# 3        GJ Maxwell
# 4         KM Jadhav
#            ...
# 751       HH Pandya
# 752        AS Yadav
# 753         RR Pant
# 754    F du Plessis
# 755       JJ Bumrah
# Name: player_of_match, Length: 756, dtype: object

# %%
# Drop any four rows from the data set.
a=df.drop(index=[3,4,5,6,7])
a
# Out:
#         id    Season           city        date                  team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017    Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017         Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017          Gujarat Lions
# 8        9  IPL-2017           Pune  11-04-2017       Delhi Daredevils
# 9       10  IPL-2017         Mumbai  12-04-2017    Sunrisers Hyderabad
# ..     ...       ...            ...         ...                    ...
# 751  11347  IPL-2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
a.head(20)
# Out:
#     id    Season       city        date                        team1  \
# 0    1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2    3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 8    9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 9   10  IPL-2017     Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  11  IPL-2017    Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017  Bangalore  14-04-2017  Royal Challengers Bangalore
# 12  13  IPL-2017     Rajkot  14-04-2017       Rising Pune Supergiant
# 13  14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14  15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
# 15  16  IPL-2017     Mumbai  16-04-2017                Gujarat Lions
# 16  17  IPL-2017  Bangalore  16-04-2017       Rising Pune Supergiant
# 17  18  IPL-2017      Delhi  17-04-2017             Delhi Daredevils
# ...

# %%
# Drop any two colmns.
b=df.drop(columns=['city','Season'])
b
# Out:
#         id        date                        team1  \
# 0        1  05-04-2017          Sunrisers Hyderabad
# 1        2  06-04-2017               Mumbai Indians
# 2        3  07-04-2017                Gujarat Lions
# 3        4  08-04-2017       Rising Pune Supergiant
# 4        5  08-04-2017  Royal Challengers Bangalore
# ..     ...         ...                          ...
# 751  11347  05-05-2019        Kolkata Knight Riders
# 752  11412  07-05-2019          Chennai Super Kings
# 753  11413  08-05-2019          Sunrisers Hyderabad
# 754  11414  10-05-2019               Delhi Capitals
# 755  11415  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# 2          Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
# find two columns and six rows from the mid.
df.iloc[250:256,1:6]
# Out:
#        Season        city        date                 team1  \
# 250  IPL-2011     Kolkata  17-04-2011      Rajasthan Royals
# 251  IPL-2011       Kochi  18-04-2011   Chennai Super Kings
# 252  IPL-2011       Delhi  19-04-2011       Deccan Chargers
# 253  IPL-2011      Mumbai  20-04-2011         Pune Warriors
# 254  IPL-2011     Kolkata  20-04-2011  Kochi Tuskers Kerala
# 255  IPL-2011  Chandigarh  21-04-2011       Kings XI Punjab
#
#                      team2
# 250  Kolkata Knight Riders
# 251   Kochi Tuskers Kerala
# 252       Delhi Daredevils
# 253         Mumbai Indians
# 254  Kolkata Knight Riders
# 255       Rajasthan Royals

# %%
# Take some data as you want and make a bar graph on this data.

# %% [markdown]
# # Applying all aggregate function

# %%
df.count()
# Out:
# id                 756
# Season             756
# city               756
# date               756
# team1              756
# team2              756
# toss_winner        756
# toss_decision      756
# result             756
# dl_applied         756
# winner             756
# win_by_runs        756
# win_by_wickets     756
# player_of_match    756
# venue              756
# umpire1            756
# umpire2            756
# umpire3            756
# dtype: int64

# %%
df.sum()
# Out:
# id                                                          1354887
# Season            IPL-2017IPL-2017IPL-2017IPL-2017IPL-2017IPL-20...
# date              05-04-201706-04-201707-04-201708-04-201708-04-...
# team1             Sunrisers HyderabadMumbai IndiansGujarat Lions...
# team2             Royal Challengers BangaloreRising Pune Supergi...
# toss_winner       Royal Challengers BangaloreRising Pune Supergi...
# toss_decision     fieldfieldfieldfieldbatfieldfieldbatfieldfield...
# result            normalnormalnormalnormalnormalnormalnormalnorm...
# dl_applied                                                       19
# win_by_runs                                                   10042
# win_by_wickets                                                 2533
# venue             Rajiv Gandhi International Stadium, UppalMahar...
# dtype: object

# %%
df.mean()
# Out:
# id                1792.178571
# dl_applied           0.025132
# win_by_runs         13.283069
# win_by_wickets       3.350529
# dtype: float64

# %%
df.max()
# Out:
# id                              11415
# Season                       IPL-2019
# date                       31-05-2008
# team1             Sunrisers Hyderabad
# team2             Sunrisers Hyderabad
# toss_winner       Sunrisers Hyderabad
# toss_decision                   field
# result                            tie
# dl_applied                          1
# win_by_runs                       146
# win_by_wickets                     10
# venue                Wankhede Stadium
# dtype: object

# %%
df.min()
# Out:
# id                                  1
# Season                       IPL-2008
# date                       01-04-2010
# team1             Chennai Super Kings
# team2             Chennai Super Kings
# toss_winner       Chennai Super Kings
# toss_decision                     bat
# result                      no result
# dl_applied                          0
# win_by_runs                         0
# win_by_wickets                      0
# venue                ACA-VDCA Stadium
# dtype: object

# %%
df.head(10)
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6  IPL-2017  Hyderabad  09-04-2017                Gujarat Lions
# 6   7  IPL-2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7   8  IPL-2017     Indore  10-04-2017  Royal Challengers Bangalore
# 8   9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 9  10  IPL-2017     Mumbai  12-04-2017          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.value_counts('win_by_runs')
# Out:
# win_by_runs
# 0      419
# 14      13
# 4       11
# 10      11
# 1       10
#       ...
# 66       1
# 64       1
# 59       1
# 62       1
# 146      1
# Length: 89, dtype: int64

# %%
df.value_counts('win_by_wickets')
# Out:
# win_by_wickets
# 0     350
# 6      85
# 7      80
# 5      71
# 8      54
# 4      41
# 9      37
# 3      18
# 10     11
# 2       6
# 1       3
# dtype: int64

# %%
df.value_counts('Season')
# Out:
# Season
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2010    60
# IPL-2014    60
# IPL-2016    60
# IPL-2018    60
# IPL-2019    60
# IPL-2015    59
# IPL-2017    59
# IPL-2008    58
# IPL-2009    57
# dtype: int64

# %%
# To make a BarPlot
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# getting the frequency of  most man of the match awards
df['player_of_match'].value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: player_of_match, Length: 227, dtype: int64

# %%
df['player_of_match'].value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: player_of_match, Length: 227, dtype: int64

# %%
df['player_of_match'].value_counts().keys()
# Out:
# Index([      'CH Gayle', 'AB de Villiers',      'RG Sharma',       'MS Dhoni',
#             'DA Warner',      'YK Pathan',      'SR Watson',       'SK Raina',
#             'G Gambhir',     'MEK Hussey',
#        ...
#              'M Kartik',      'R McLaren',      'RJ Harris',       'TL Suman',
#               'MJ Lumb', 'PD Collingwood',        'NV Ojha',       'AC Voges',
#              'J Theron',      'S Hetmyer'],
#       dtype='object', length=227)

# %%
# getting the top 10 players with most man of the matches 
df['player_of_match'].value_counts()[0:10]
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
# getting the top 5 players of the man of the match
df['player_of_match'].value_counts()[0:5]
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# Name: player_of_match, dtype: int64

# %%
# Making the Bar-Plot for the top 5 Players with most of the match awards 
plt.figure(figsize = (8,5))
plt.bar(list(df['player_of_match'].value_counts()[0:5].keys()),list(df['player_of_match'].value_counts()[0:5]),color='teal')
plt.show()

# %%
# getting the frequncy of the result coumn 
df['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
# finding the toss winner
df['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
# extracting the records where a team won batting first
batting_first=df[df['win_by_runs']!=0]
batting_first
# Out:
#         id    Season       city        date                        team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8        9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13      14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14      15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
# ..     ...       ...        ...         ...                          ...
# 741  11337  IPL-2019      Delhi  28-04-2019               Delhi Capitals
# 742  11338  IPL-2019    Kolkata  28-04-2019        Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019          Sunrisers Hyderabad
# 745  11341  IPL-2019    Chennai  01-05-2019          Chennai Super Kings
# 755  11415  IPL-2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
'''# extracting the records where a team won by 15 runs  first
batting_first=df[df['win_by_runs']==15]
batting_first'''
# Out:
# "# extracting the records where a team won by 15 runs  first\nbatting_first=df[df['win_by_runs']==15]\nbatting_first"

# %%
# Making a Histogram
plt.figure(figsize=(8,7))
plt.hist(batting_first['win_by_runs'],color='brown')
plt.title('Distribution of Runs')
plt.xlabel('Runs')
plt.show()

# %%
batting_first['winner'].value_counts()
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
# Finding Out the number of wins w.r.t each team aftee batting first
a=batting_first['winner'].value_counts()[0:3]
print(a)
# Out:
# Mumbai Indians         57
# Chennai Super Kings    52
# Kings XI Punjab        38
# Name: winner, dtype: int64

# %%
# Finding the keys
b=list(batting_first['winner'].value_counts().keys()[0:3])
print(b)
# Out:
# ['Mumbai Indians', 'Chennai Super Kings', 'Kings XI Punjab']

# %%
# finding the values 
c=list(batting_first['winner'].value_counts()[0:3])
print(c)
# Out:
# [57, 52, 38]

# %%
plt.pie(a,labels=b)
plt.pie(a,labels=b,autopct='%0.1f%%')
plt.show()

# %% [markdown]
# # apply all aggregate function on this data set

# %%
# reversing the series 
x =pd.Series([34,45,76,23,89,98,100,123,456,789,56,67,89,111])
print(x[::-1])
# Out:
# 13    111
# 12     89
# 11     67
# 10     56
# 9     789
# 8     456
# 7     123
# 6     100
# 5      98
# 4      89
# 3      23
# 2      76
# 1      45
# 0      34
# dtype: int64

# %% [markdown]
# # Zomato DataSet Project

# %%
z=pd.read_csv("C:/Users/hp/OneDrive/Desktop/zomato_1.csv.xls")
z
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
1.Tell me the total rows and columns of this data set. 
2.Tell me the total description about this data set.
3.Find the all information about this data set. 
4.Find the null value of this data set. 
5.Fill the null values of this data set. 
6.How many total resturants are present in this data set. 
7.How many DominosPizza names resturants are present in this data set.
8.How many types of food they provide.
9 How many online delivery they provide.
10. How many table book in their resturants.
11. Tell us first five cities where these resturants are present and how many.
12. Tell us how many ratings they are provide.
13. Tell me the name of these resturants which one get the best ratings.
14.Tell me the name of these resturants which one get the Poor ratings.
15.Tell me the name of these resturants which one get the Average ratings.
16.Find the first five resturants name who will get maximum votes.

# %%
# 1.Tell me the total rows and columns of this data set. 
z.shape
# Out:
# (9551, 21)

# %%
# 2.Tell me the total description about this data set.
z.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# 3.Find the all information about this data set.
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# 4.Find the null value of this data set.
null_value_total=z.isnull().sum()
null_value_total
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
null_value=z.isnull()
null_value
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
null_value.shape
# Out:
# (9551, 21)

# %%
# 5.Fill the null values of this data set. 
z.fillna('Indian',inplace=True)

# %%
z.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# 6.How many total resturants are present in this data set.
a=z.loc[:,'Restaurant Name']
print(a)
a.shape
# Out:
# 0               Le Petit Souffle
# 1               Izakaya Kikufuji
# 2         Heat - Edsa Shangri-La
# 3                           Ooma
# 4                    Sambo Kojin
#                   ...
# 9546                NamlÛ± Gurme
# 9547               Ceviz AÛôacÛ±
# 9548                       Huqqa
# 9549                Aôôk Kahve
# 9550    Walter's Coffee Roastery
# Name: Restaurant Name, Length: 9551, dtype: object
# (9551,)

# %%
z.count()
# Out:
# Restaurant ID           9551
# Restaurant Name         9551
# Country Code            9551
# City                    9551
# Address                 9551
# Locality                9551
# Locality Verbose        9551
# Longitude               9551
# Latitude                9551
# Cuisines                9551
# Average Cost for two    9551
# Currency                9551
# Has Table booking       9551
# Has Online delivery     9551
# Is delivering now       9551
# Switch to order menu    9551
# Price range             9551
# Aggregate rating        9551
# Rating color            9551
# Rating text             9551
# Votes                   9551
# dtype: int64

# %%
# 7.How many DominosPizza names resturants are present in this data set.
# 6.How many total resturants are present in this data set.
a=z[z['Restaurant Name']=="Domino's Pizza"]
a
# Out:
#       Restaurant ID Restaurant Name  Country Code        City  \
# 709         2500134  Domino's Pizza             1  Aurangabad
# 1052         309632  Domino's Pizza             1   Faridabad
# 1130       18168161  Domino's Pizza             1   Ghaziabad
# 1192            227  Domino's Pizza             1     Gurgaon
# 1263            225  Domino's Pizza             1     Gurgaon
# ...             ...             ...           ...         ...
# 8749            385  Domino's Pizza             1       Noida
# 8861           1844  Domino's Pizza             1       Noida
# 8987       18354978  Domino's Pizza             1       Noida
# 9068            386  Domino's Pizza             1       Noida
# 9078           5619  Domino's Pizza             1       Noida
#
#                                                 Address  \
# 709   8, Upper Ground Floor, City Pride Commercial C...
# 1052  Ground Floor, Plot 201, Block B, Greenfield Co...
# ...

# %%
a.shape
# Out:
# (79, 21)

# %%
# 6.How many total resturants are present in this data set.
x=z.value_counts('Restaurant Name')
x
# Out:
# Restaurant Name
# Cafe Coffee Day                            83
# Domino's Pizza                             79
# Subway                                     63
# Green Chick Chop                           51
# McDonald's                                 48
#                                            ..
# Ghungroo Club & Bar - By Gautam Gambhir     1
# Ghar Ki Handi                               1
# Ghar Ka Swad                                1
# Ghar Bistro Cafe                            1
# íˆukuraÛôa SofrasÛ±                         1
# Length: 7446, dtype: int64

# %%
import seaborn as sns

# %%
sns.histplot(z['Restaurant Name'],bins=30)
plt.show()

# %%
# use of count()method
# return count of appearanve of pattern in each element;
x=pd.Series(['Ashish','Arvind','Raju','Mohit','Suraj'])
print(x.str.count('a'))
print(x.str.count('sh'))

# %%
z.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# 8.How many types of food they provide.
x=z.value_counts('Cuisines')
x
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Continental, Italian, North Indian, Lebanese, Thai         1
# Continental, Italian, North Indian, Lebanese               1
# Continental, Italian, North Indian, Chinese, Lebanese      1
# Continental, Italian, North Indian, Chinese                1
# World Cuisine, Patisserie, Cafe                            1
# Length: 1825, dtype: int64

# %%
x.shape
# Out:
# (1825,)

# %%
# 9 How many online delivery they provide.
x=z.value_counts('Has Online delivery')
x
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# dtype: int64

# %%
# 10. How many table book in their resturants.
z.value_counts('Has Table booking')
# Out:
# Has Table booking
# No     8393
# Yes    1158
# dtype: int64

# %%
# 11. Tell us first five cities where these resturants are present and how many.
z['Locality Verbose'].value_counts()[0:5]
# Out:
# Connaught Place, New Delhi    122
# Rajouri Garden, New Delhi      99
# Shahdara, New Delhi            87
# Defence Colony, New Delhi      86
# Pitampura, New Delhi           85
# Name: Locality Verbose, dtype: int64

# %%
sns.histplot(z['Locality Verbose'],bins=30)
plt.show()

# %%
# 12. Tell us how many ratings they are provide.
z.value_counts('Rating text')
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# dtype: int64

# %%
# 13. Tell me the name of these resturants which one get the best ratings.
a=z[z['Rating text']=='Excellent']
a
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 0           6317637                          Le Petit Souffle           162
# 1           6304287                          Izakaya Kikufuji           162
# 3           6318506                                      Ooma           162
# 4           6314302                               Sambo Kojin           162
# 8           6300010  Spiral - Sofitel Philippine Plaza Manila           162
# ...             ...                                       ...           ...
# 9537        5904116                       J'adore Chocolatier           208
# 9538        5901782                                 Starbucks           208
# 9540        5927248                          Draft Gastro Pub           208
# 9543        5916085                              Dem Karakí_y           208
# 9544        5915547                     Karakí_y Gí_llí_oÛôlu           208
#
# ...

# %%
a.shape
# Out:
# (301, 21)

# %%
# 14.Tell me the name of these resturants which one get the Poor ratings.
a=z[z['Rating text']=='Poor']
a
# Out:
#       Restaurant ID                  Restaurant Name  Country Code  \
# 312        17374978                     Troll Tavern           216
# 344        17482142              Triangle Restaurant           216
# 348        16613059                       Poets Cafe            14
# 613         5600961                        Pizza Hut           214
# 890          311051                              KFC             1
# ...             ...                              ...           ...
# 9104           2979                          Chopaal             1
# 9105           3237                    Club Ice Cube             1
# 9106           2025  Moti Mahal Delux Tandoori Trail             1
# 9306        7001208     De Fontein Belgian Beer Cafe           148
# 9498        5800634          Elite Indian Restaurant           191
#
#              City                                            Address  \
# 312   Gainesville              8590 N Main St Ste B, Helen, GA 30545
# ...

# %%
a.shape
# Out:
# (186, 21)

# %%
# 15.Tell me the name of these resturants which one get the Average ratings.
a=z[z['Rating text']=='Average']
a
# Out:
#       Restaurant ID      Restaurant Name  Country Code       City  \
# 22          6600681          Chez Michou            30  Brasí_lia
# 26          6600970       Pizza íæ Bessa            30  Brasí_lia
# 27          6600379           Sushi Loko            30  Brasí_lia
# 32          6601515             Rovereto            30  Brasí_lia
# 38          6601158              Manzuíç            30  Brasí_lia
# ...             ...                  ...           ...        ...
# 9418        6201976  Indian Coffee House           166       Doha
# 9476          75104             Parrot's           189   Pretoria
# 9497        5800557  Chinese Dragon Cafe           191    Colombo
# 9507        5800156         Queen's Cafe           191    Colombo
# 9521        6003426                 Liva           208     Ankara
#
#                                                 Address  \
# 22    SCLN, 208, Bloco A, Loja 30, Asa Norte, Brasí_lia
# 26        SCS 214, Bloco C, Loja 40, Asa Sul, Brasí_lia
# ...

# %%
a.shape
# Out:
# (3737, 21)

# %%
# 16.Find the first five resturants name who will get maximum votes.
z[z['Rating text']=='Excellent']

# %%
a=z.value_counts('Votes')
a.head(50)
# Out:
# Votes
# 0     1094
# 1      483
# 2      327
# 3      244
# 4      207
# 7      168
# 5      164
# 6      154
# 10     135
# 8      134
# 11     124
# 9      113
# 14     104
# 12     100
# 13      95
# 15      93
# 16      93
# 18      84
# 26      80
# 17      79
# 21      76
# 27      72
# 25      71
# 20      70
# 19      68
# 23      68
# 22      64
# 31      63
# 33      61
# 24      58
# 29      56
# 32      55
# 49      49
# 35      47
# 34      46
# 28      45
# 39      45
# 30      43
# 38      42
# 36      42
# 40      40
# 45      40
# 41      39
# 46      36
# 43      35
# 37      35
# 51      34
# 57      34
# 69      34
# 42      33
# dtype: int64
